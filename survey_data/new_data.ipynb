# %%
import pandas as pd
import numpy as np
import random

# %%
df = pd.read_csv("Dummy Data Responses.csv")
newDF = df.copy()

# %%
allVals = dict()
for x in newDF.columns:
    allVals[x] = dict(newDF[x].value_counts())

def update(index, col):
    val, left = random.choice(list(allVals[col].items()))
    newDF.at[index, col] = val
    if (left == 1):
        allVals[col].pop(val)

# %%
cols = '''COL1	COL2	COL3	COL4	COL5	COL6	COL7	COL8	COL9	COL10	COL11	COL12	COL13	COL14	COL15	COL16	COL17	COL18	COL19	COL20	COL21	COL22	COL23	COL24	COL25	COL26	COL27	COL28	COL29	COL30	COL31	COL32	COL33	COL34	COL35	COL36	COL37	COL38	COL39	COL40	COL41	COL42	COL43	COL44'''
colsDict = {}
for x, y in enumerate(cols.split()):
    colsDict[x+1] = y
toRemove = [5, 6, 8, 9, 10, 11, 13, 14, 16, 17, 18, 19, 21, 22, 24, 25, 26, 28, 29, 30, 31, 32, 34, 35, 37, 38, 40, 41, 43, 44]
for x in toRemove:
    colsDict.pop(x)
def findNext(x):
    a = x + 1
    while (a not in colsDict and a < 45):
        a += 1
    colsDict[x] = a
for i in sorted(colsDict.keys(), reverse=True):
    findNext(i)
colsDict
# Out:
# {1: 2,
#  2: 3,
#  3: 4,
#  4: 7,
#  7: 12,
#  12: 15,
#  15: 20,
#  20: 23,
#  23: 27,
#  27: 33,
#  33: 36,
#  36: 39,
#  39: 42,
#  42: 45}

# %%
# start is key, value is dict with key of selection and value of freq
freqTable = {}
for k in colsDict.keys():
    freqTable[k] = {}

# %%
for index, row in newDF.iterrows():
    for start, end in colsDict.items():
        toAppend = [] 
        for i in range(start, end):
            toAppend.append(newDF.at[index, "COL"+str(i)])
        if tuple(toAppend) not in freqTable[start]:
            freqTable[start][tuple(toAppend)] = 1
        else:
            freqTable[start][tuple(toAppend)] += 1

# %%
freqTable
# Out:
# {1: {(22,): 11,
#   (23,): 9,
#   (24,): 9,
#   (21,): 8,
#   (25,): 4,
#   (20,): 1,
#   (27,): 1,
#   (30,): 2,
#   (39,): 1,
#   (18,): 1,
#   (19,): 1,
#   (29,): 1},
#  2: {('Chinese',): 39, ('Indian',): 7, ('Malay',): 2, ('Eurasian',): 1},
#  3: {('Singaporean',): 47, ('Indian',): 2},
#  4: {('I do not live in a HDB Town', 'Private', 'Terrace'): 3,
#   ('Punggol', 'Public Housing (HDB)', '4-Room'): 2,
#   ('Ang Mo Kio', 'Public Housing (HDB)', '4-Room'): 2,
#   ('Woodlands', 'Public Housing (HDB)', '4-Room'): 1,
#   ('Choa Chu Kang', 'Public Housing (HDB)', '5-Room'): 2,
#   ('Bishan', 'Public Housing (HDB)', 'Executive Flat'): 2,
#   ('Tampines', 'Public Housing (HDB)', '5-Room'): 1,
#   ('Tampines', 'Public Housing (HDB)', '4-Room'): 1,
#   ('Bishan', 'Public Housing (HDB)', '5-Room'): 2,
#   ('Woodlands', 'Private', 'Bungalow'): 1,
#   ('Bishan', 'Private', 'Semi-detached'): 1,
#   ('Bukit Timah', 'Private', 'Condominium'): 1,
#   ('Hougang', 'Public Housing (HDB)', '4-Room'): 1,
#   ('Jurong East', 'Public Housing (HDB)', 'Executive Flat'): 1,
#   ('Yishun', 'Public Housing (HDB)', 'Mansionette'): 1,
#   ('Bukit Panjang', 'Private', 'Condominium'): 1,
#   ('Woodlands', 'Public Housing (HDB)', '3-Room'): 1,
#   ('Hougang', 'Private', 'Semi-detached'): 1,
#   ('Ang Mo Kio', 'Public Housing (HDB)', '5-Room'): 1,
#   ('Bedok', 'Public Housing (HDB)', '5-Room'): 2,
#   ('I do not live in a HDB Town', 'Private', 'Condominium'): 1,
#   ('Queenstown', 'Private', 'Condominium'): 2,
#   ('I do not live in a HDB Town', 'Private', 'Bungalow'): 1,
#   ('Clementi', 'Public Housing (HDB)', '4-Room'): 1,
#   ('Bishan', 'Private', 'Condominium'): 1,
#   ('I do not live in a HDB Town', 'Private', 'Detached'): 1,
#   ('Clementi', 'Private', 'Condominium'): 2,
#   ('Woodlands', 'Public Housing (HDB)', 'Executive Flat'): 1,
#   ('Serangoon', 'Private', 'Condominium'): 1,
#   ('Pasir Ris', 'Public Housing (HDB)', 'Executive Flat'): 1,
#   ('Pasir Ris', 'Public Housing (HDB)', '5-Room'): 2,
#   ('Bukit Batok', 'Public Housing (HDB)', '4-Room'): 1,
#   ('Sengkang', 'Public Housing (HDB)', '4-Room'): 1,
#   ('Tampines', 'Private', 'Condominium'): 1,
#   ('Bishan', 'Public Housing (HDB)', '4-Room'): 1,
#   ('Choa Chu Kang', 'Public Housing (HDB)', '4-Room'): 1,
#   ('Hougang', 'Private', 'Condominium'): 1,
#   ('Jurong West', 'Public Housing (HDB)', '4-Room'): 1},
#  7: {('1 to 10', '0', 5.5, 0.0, 0.0): 16,
#   ('0', '0', 0.0, 0.0, 0.0): 19,
#   ('1 to 10', '1 to 10', 5.5, 5.5, 1.0): 11,
#   ('11 to 20', '1 to 10', 15.5, 5.5, 0.35): 3},
#  12: {('Sometimes', 'Never', 'Along the street or when house visiting'): 1,
#   ('Sometimes', 'Never', 'Neighbourhood shopping mall'): 4,
#   ('Never', 'Never', 'Neighbourhood shopping mall'): 1,
#   ('Never', 'Never', 'No friends in neighbourhood'): 18,
#   ('Sometimes', 'Never', 'Each others house'): 1,
#   ('Frequently',
#    'Sometimes',
#    'Neighbourhood Eatery (Hawker Centres/Cafes/etc)'): 1,
#   ('About half the time', 'About half the time', 'at work & school, gym'): 1,
#   ('About half the time', 'Sometimes', 'Corridors and void decks'): 1,
#   ('Sometimes', 'Never', 'Neighbourhood Eatery (Hawker Centres/Cafes/etc)'): 1,
#   ('Frequently',
#    'Frequently',
#    'Neighbourhood Park/Playground/Fitness Corner'): 1,
#   ('Sometimes', 'Sometimes', 'Neighbourhood shopping mall'): 3,
#   ('Sometimes', 'Never', 'No friends in neighbourhood'): 1,
#   ('Sometimes', 'Sometimes', 'Each others house'): 2,
#   ('Never', 'Never', 'Each others house'): 1,
#   ('Sometimes', 'Sometimes', 'Neighbourhood CC/RC activities'): 2,
#   ('Sometimes', 'Never', 'Walking in and out of residence'): 1,
#   ('Sometimes', 'Never', 'Neighbourhood CC/RC activities'): 1,
#   ('Sometimes',
#    'Sometimes',
#    'Neighbourhood Eatery (Hawker Centres/Cafes/etc)'): 1,
#   ('Frequently', 'Sometimes', 'school'): 1,
#   ('Frequently', 'Never', 'Each others house'): 1,
#   ('About half the time',
#    'Never',
#    'Neighbourhood Eatery (Hawker Centres/Cafes/etc)'): 1,
#   ('Sometimes',
#    'Sometimes',
#    'Neighbourhood Park/Playground/Fitness Corner'): 1,
#   ('Sometimes', 'Never', 'school'): 1,
#   ('Sometimes', 'Never', 'Neighbourhood Park/Playground/Fitness Corner'): 1,
#   ('Sometimes', 'Never', 'Know from uni, happen to live nearby'): 1},
#  15: {('Never',
#    'Never',
#    'Sometimes',
#    'Never',
#    'In their houses or along the street'): 1,
#   ('Sometimes',
#    'Sometimes',
#    'Sometimes',
#    'Sometimes',
#    'See them say hi outside their house'): 1,
#   ('Sometimes',
#    'Sometimes',
#    'Sometimes',
#    'Sometimes',
#    'Neighbourhood Eatery (Hawker Centres/Cafes/etc)'): 2,
#   ('About half the time',
#    'About half the time',
#    'Never',
#    'Never',
#    'Neighbourhood Park/Playground/Fitness Corner'): 1,
#   ('Sometimes', 'Sometimes', 'Never', 'Never', 'No neighbours'): 2,
#   ('Never', 'Never', 'Never', 'Never', nan): 1,
#   ('About half the time',
#    'About half the time',
#    'About half the time',
#    'About half the time',
#    'In our corridor'): 1,
#   ('Sometimes',
#    'Sometimes',
#    'Sometimes',
#    'Sometimes',
#    'Lift and lift lobby'): 1,
#   ('About half the time',
#    'Sometimes',
#    'Sometimes',
#    'Sometimes',
#    'Corridors, void decks and provision shops'): 1,
#   ('Sometimes',
#    'Sometimes',
#    'Sometimes',
#    'Sometimes',
#    'Neighbourhood Park/Playground/Fitness Corner'): 4,
#   ('Sometimes', 'Never', 'Sometimes', 'Never', 'House corridors '): 1,
#   ('Never',
#    'Never',
#    'Sometimes',
#    'Sometimes',
#    'Neighbourhood shopping mall'): 1,
#   ('Frequently',
#    'Frequently',
#    'Frequently',
#    'Frequently',
#    'Neighbourhood Park/Playground/Fitness Corner'): 1,
#   ('Sometimes',
#    'About half the time',
#    'Sometimes',
#    'Never',
#    'Lift lobbies'): 1,
#   ('Sometimes',
#    'Never',
#    'Sometimes',
#    'Never',
#    'Neighbourhood Eatery (Hawker Centres/Cafes/etc)'): 1,
#   ('About half the time',
#    'Sometimes',
#    'Sometimes',
#    'Sometimes',
#    'In the lifts'): 1,
#   ('Sometimes', 'Never', 'Never', 'Never', 'No neighbours'): 2,
#   ('Sometimes', 'Sometimes', 'Sometimes', 'Never', 'No neighbours'): 1,
#   ('Sometimes', 'Never', 'Sometimes', 'Never', 'No neighbours'): 2,
#   ('Never', 'Never', 'Sometimes', 'Never', 'No neighbours'): 2,
#   ('Sometimes', 'Sometimes', 'Sometimes', 'Never', 'In the lift'): 1,
#   ('Sometimes', 'Never', 'Never', 'Never', 'House corridors '): 1,
#   ('Very Frequently',
#    'Very Frequently',
#    'Never',
#    'Never',
#    'Within the condominium '): 1,
#   ('Sometimes', 'Never', 'Sometimes', 'Never', 'At HDB block'): 1,
#   ('Never', 'Never', 'Never', 'Never', 'At HDB block'): 1,
#   ('Sometimes',
#    'Sometimes',
#    'Sometimes',
#    'Sometimes',
#    'Usually in passing at the lobby'): 1,
#   ('Never', 'Never', 'Never', 'Never', 'No neighbours'): 1,
#   ('Sometimes',
#    'Sometimes',
#    'Sometimes',
#    'Sometimes',
#    'Within the condo compound'): 1,
#   ('About half the time',
#    'Sometimes',
#    'Sometimes',
#    'Never',
#    'Neighbourhood shopping mall'): 1,
#   ('Sometimes',
#    'Sometimes',
#    'Sometimes',
#    'Sometimes',
#    'Walking in and out of residence'): 1,
#   ('Never',
#    'Never',
#    'Sometimes',
#    'Never',
#    'Neighbourhood Park/Playground/Fitness Corner'): 2,
#   ('Sometimes',
#    'Never',
#    'Sometimes',
#    'Never',
#    'Neighbourhood Park/Playground/Fitness Corner'): 2,
#   ('Sometimes', 'Sometimes', 'Sometimes', 'Never', 'House corridors '): 1,
#   ('About half the time', 'Sometimes', 'Never', 'Never', 'At HDB block'): 1,
#   ('Never',
#    'Never',
#    'Never',
#    'Never',
#    'I have neighbours but I don’t interact with them'): 1,
#   ('Sometimes', 'Sometimes', 'Sometimes', 'Sometimes', 'in the lifts'): 1,
#   ('Never', 'Never', 'Never', 'Never', 'NUS'): 1,
#   ('Sometimes', 'Sometimes', 'Sometimes', 'Sometimes', 'In the lift'): 1,
#   ('Sometimes',
#    'Sometimes',
#    'Never',
#    'Never',
#    'Neighbourhood Eatery (Hawker Centres/Cafes/etc)'): 1},
#  20: {('Neither agree nor disagree', 'Somewhat agree', 'Strongly agree'): 3,
#   ('Somewhat disagree', 'Somewhat agree', 'Somewhat agree'): 12,
#   ('Somewhat disagree',
#    'Neither agree nor disagree',
#    'Neither agree nor disagree'): 3,
#   ('Somewhat agree', 'Somewhat agree', 'Somewhat agree'): 3,
#   ('Neither agree nor disagree', 'Strongly agree', 'Strongly agree'): 4,
#   ('Neither agree nor disagree',
#    'Neither agree nor disagree',
#    'Neither agree nor disagree'): 2,
#   ('Somewhat disagree', 'Somewhat disagree', 'Neither agree nor disagree'): 1,
#   ('Strongly disagree', 'Somewhat agree', 'Strongly agree'): 1,
#   ('Somewhat disagree', 'Strongly agree', 'Somewhat agree'): 1,
#   ('Strongly agree', 'Strongly agree', 'Strongly agree'): 1,
#   ('Neither agree nor disagree',
#    'Somewhat disagree',
#    'Neither agree nor disagree'): 2,
#   ('Neither agree nor disagree', 'Somewhat agree', 'Somewhat agree'): 6,
#   ('Somewhat agree', 'Somewhat disagree', 'Neither agree nor disagree'): 1,
#   ('Somewhat agree', 'Somewhat agree', 'Strongly agree'): 1,
#   ('Somewhat agree',
#    'Neither agree nor disagree',
#    'Neither agree nor disagree'): 1,
#   ('Strongly disagree',
#    'Neither agree nor disagree',
#    'Neither agree nor disagree'): 1,
#   ('Strongly disagree', 'Strongly agree', 'Strongly agree'): 1,
#   ('Strongly disagree', 'Strongly agree', 'Somewhat agree'): 1,
#   ('Neither agree nor disagree', 'Strongly agree', 'Somewhat agree'): 1,
#   ('Strongly disagree', 'Somewhat agree', 'Somewhat agree'): 1,
#   ('Strongly disagree', 'Somewhat disagree', 'Strongly disagree'): 1,
#   ('Somewhat agree', 'Neither agree nor disagree', 'Strongly agree'): 1},
#  23: {('Very frequently',
#    'Frequently',
#    'Very frequently',
#    'Very frequently'): 2,
#   ('Very frequently', 'Sometimes', 'Very frequently', 'Sometimes'): 2,
#   ('Sometimes', 'Sometimes', 'Frequently', 'Frequently'): 2,
#   ('Never', 'Never', 'Never', 'Never'): 1,
#   ('Sometimes', 'Sometimes', 'Sometimes', 'Sometimes'): 1,
#   ('About half the time',
#    'About half the time',
#    'About half the time',
#    'About half the time'): 1,
#   ('About half the time',
#    'Sometimes',
#    'Very frequently',
#    'Very frequently'): 2,
#   ('Very frequently',
#    'About half the time',
#    'Very frequently',
#    'Frequently'): 2,
#   ('Frequently', 'Very frequently', 'Very frequently', 'Very frequently'): 1,
#   ('Very frequently', 'Frequently', 'Very frequently', 'Frequently'): 1,
#   ('Sometimes', 'Sometimes', 'Very frequently', 'Frequently'): 1,
#   ('About half the time',
#    'About half the time',
#    'Frequently',
#    'About half the time'): 1,
#   ('About half the time',
#    'About half the time',
#    'Very frequently',
#    'Very frequently'): 1,
#   ('About half the time', 'Sometimes', 'Frequently', 'Frequently'): 1,
#   ('Sometimes', 'Sometimes', 'Very frequently', 'Very frequently'): 3,
#   ('Very frequently',
#    'Very frequently',
#    'Very frequently',
#    'Very frequently'): 6,
#   ('Sometimes',
#    'About half the time',
#    'Very frequently',
#    'About half the time'): 3,
#   ('Never', 'Never', 'Frequently', 'About half the time'): 3,
#   ('Sometimes', 'About half the time', 'Frequently', 'About half the time'): 2,
#   ('Frequently',
#    'About half the time',
#    'Frequently',
#    'About half the time'): 2,
#   ('Never', 'Never', 'About half the time', 'About half the time'): 1,
#   ('Frequently', 'About half the time', 'Frequently', 'Frequently'): 1,
#   ('Never', 'Never', 'Never', 'Sometimes'): 1,
#   ('Frequently', 'Sometimes', 'Very frequently', 'Sometimes'): 1,
#   ('Never', 'Never', 'Frequently', 'Never'): 2,
#   ('Frequently', 'Sometimes', 'Frequently', 'Sometimes'): 3,
#   ('About half the time', 'Sometimes', 'About half the time', 'Sometimes'): 1,
#   ('Sometimes', 'Sometimes', 'Sometimes', 'Frequently'): 1},
#  27: {('21 to 30',
#    '1 to 10',
#    25.5,
#    5.5,
#    0.22,
#    'At work, in school, or when we go out to eat'): 1,
#   ('21 to 30', '1 to 10', 25.5, 5.5, 0.22, 'School '): 1,
#   ('41 to 50', '31 to 40', 45.5, 35.5, 0.78, 'School, etc'): 1,
#   ('0', '0', 0.0, 0.0, 0.0, 'nq'): 1,
#   ('1 to 10', '0', 5.5, 0.0, 0.0, 'Their home'): 1,
#   ('11 to 20', '1 to 10', 15.5, 5.5, 0.35, 'School'): 8,
#   ('More than 100', '21 to 30', 105.5, 25.5, 0.24, 'University'): 1,
#   ('21 to 30', '1 to 10', 25.5, 5.5, 0.22, 'school'): 2,
#   ('41 to 50',
#    '11 to 20',
#    45.5,
#    15.5,
#    0.34,
#    'university, workplace, meals'): 1,
#   ('21 to 30',
#    '11 to 20',
#    25.5,
#    15.5,
#    0.61,
#    'Shopping centres and malls, in school (university)'): 1,
#   ('21 to 30', '1 to 10', 25.5, 5.5, 0.22, 'Orchard/Dhoby Ghaut/NUS'): 1,
#   ('41 to 50', '11 to 20', 45.5, 15.5, 0.34, 'School'): 1,
#   ('More than 100',
#    'More than 100',
#    105.5,
#    105.5,
#    1.0,
#    'School, work, restaurants'): 1,
#   ('21 to 30', '1 to 10', 25.5, 5.5, 0.22, 'School'): 3,
#   ('11 to 20', '1 to 10', 15.5, 5.5, 0.35, 'School, Workplace'): 1,
#   ('More than 100',
#    'More than 100',
#    105.5,
#    105.5,
#    1.0,
#    'School, malls, their houses'): 1,
#   ('11 to 20',
#    '1 to 10',
#    15.5,
#    5.5,
#    0.35,
#    'shopping malls, restaurants, friends house'): 3,
#   ('31 to 40', '11 to 20', 35.5, 15.5, 0.44, 'workplace'): 1,
#   ('31 to 40', '1 to 10', 35.5, 5.5, 0.15, 'School'): 2,
#   ('21 to 30', '1 to 10', 25.5, 5.5, 0.22, 'School, malls'): 2,
#   ('11 to 20', '11 to 20', 15.5, 15.5, 1.0, 'School'): 1,
#   ('51 to 60', '51 to 60', 55.5, 55.5, 1.0, 'School'): 2,
#   ('11 to 20', '1 to 10', 15.5, 5.5, 0.35, 'Malls, food places'): 1,
#   ('91 to 100', '21 to 30', 95.5, 25.5, 0.27, 'Church and School'): 1,
#   ('71 to 80', '51 to 60', 75.5, 55.5, 0.74, 'School / bars / nightclubs'): 1,
#   ('More than 100', '51 to 60', 105.5, 55.5, 0.53, 'Malls or eateries '): 1,
#   ('71 to 80', '1 to 10', 75.5, 5.5, 0.07, 'Home '): 1,
#   ('More than 100', '1 to 10', 105.5, 5.5, 0.05, 'Home '): 1,
#   ('61 to 70', '1 to 10', 65.5, 5.5, 0.08, 'School'): 1,
#   ('51 to 60', '1 to 10', 55.5, 5.5, 0.1, 'NUS'): 1,
#   ('21 to 30', '11 to 20', 25.5, 15.5, 0.61, 'School / Work'): 1,
#   ('11 to 20', '1 to 10', 15.5, 5.5, 0.35, 'NUS'): 1,
#   ('21 to 30', '11 to 20', 25.5, 15.5, 0.61, 'At their parks or houses '): 1,
#   ('More than 100', 'More than 100', 105.5, 105.5, 1.0, 'Malls, school'): 1},
#  33: {('Strongly agree', 'Strongly agree', 'Strongly agree'): 10,
#   ('Somewhat agree', 'Strongly agree', 'Strongly agree'): 10,
#   ('Somewhat agree', 'Somewhat agree', 'Somewhat agree'): 19,
#   ('Neither agree nor disagree',
#    'Neither agree nor disagree',
#    'Neither agree nor disagree'): 2,
#   ('Somewhat agree', 'Somewhat agree', 'Strongly agree'): 1,
#   ('Strongly agree', 'Somewhat agree', 'Somewhat agree'): 2,
#   ('Neither agree nor disagree', 'Strongly agree', 'Strongly agree'): 2,
#   ('Strongly agree',
#    'Neither agree nor disagree',
#    'Neither agree nor disagree'): 1,
#   ('Somewhat agree', 'Strongly agree', 'Somewhat agree'): 1,
#   ('Neither agree nor disagree', 'Somewhat agree', 'Somewhat agree'): 1},
#  36: {('MRT Stations', 'Bus Stops', 'Shopping Mall'): 14,
#   ('MRT Stations', 'Shopping Mall', 'Sport facilities'): 1,
#   ('Bus Stops', 'Shopping Mall', 'MRT Stations'): 1,
#   ('Bus Stops', 'MRT Stations', 'Shopping Mall'): 5,
#   ('MRT Stations', 'Shopping Mall', 'Secondary School'): 1,
#   ('Place of Worship', 'MRT Stations', 'Shopping Mall'): 1,
#   ('MRT Stations', 'Shopping Mall', 'Bus Stops'): 5,
#   ('MRT Stations', 'Shopping Mall', 'Eateries'): 1,
#   ('MRT Stations', 'Tertiary Institution', 'Shopping Mall'): 1,
#   ('Shopping Mall', 'MRT Stations', 'Parks'): 1,
#   ('MRT Stations', 'Bus Stops', 'Coffee shop'): 1,
#   ('Shopping Mall', 'MRT Stations', 'Bus Stops'): 1,
#   ('MRT stations', 'Bus Stops', 'Primary School'): 1,
#   ('Shopping Mall', 'MRT stations', 'Bus Stops'): 3,
#   ('MRT stations', 'Bus Stops', 'Shopping Mall'): 3,
#   ('MRT stations', 'Shopping Mall', 'Bus Stops'): 2,
#   ('MRT stations', 'Bus Stops', 'Hawker Centre'): 2,
#   ('Bus Stops', 'MRT stations', 'Primary School'): 1,
#   ('Bus Stops', 'Childcare', 'Shopping Mall'): 1,
#   ('Places where food can be purchased (eg market, supermarket, hawker centre, coffee shop, F&B outlets)',
#    'MRT stations',
#    'Primary School'): 1,
#   ('Hawker Centre', 'Bus Stops', 'MRT stations'): 1,
#   ('MRT stations', 'Shopping Mall', 'Cheap food options'): 1},
#  39: {('School Reputation', 'Subjects Offered', 'School Curriculum'): 1,
#   ('School Curriculum', 'School Reputation', 'Distance from Home'): 5,
#   ('School Reputation', 'School Curriculum', 'Distance from Home'): 4,
#   ('School Reputation', 'Distance from Home', 'School Curriculum'): 7,
#   ('School Curriculum', 'School Reputation', 'Extracurricular Programmes'): 1,
#   ('Subjects Offered', 'Distance from Home', 'School Reputation'): 1,
#   ('School Curriculum', 'Distance from Home', 'Subjects Offered'): 2,
#   ('Subjects Offered', 'School Reputation', 'Distance from Home'): 1,
#   ('School Curriculum', 'Subjects Offered', 'Extracurricular Programmes'): 1,
#   ('School Curriculum', 'Distance from Home', 'School Reputation'): 1,
#   ('School Reputation', 'School Curriculum', 'Extracurricular Programmes'): 3,
#   ('School Curriculum', 'Extracurricular Programmes', 'Distance from Home'): 1,
#   ('School Curriculum', 'School Reputation', 'Subjects Offered'): 8,
#   ('Distance from Home', 'School Reputation', 'School Curriculum'): 2,
#   ('School Reputation', 'School Curriculum', 'Subjects Offered'): 3,
#   ('School Curriculum', 'Subjects Offered', 'School Reputation'): 1,
#   ('Distance from Home', 'Subjects Offered', 'School Reputation'): 2,
#   ('School Reputation',
#    'People and culture (eg classmates, students, teaching staff)',
#    'School Curriculum'): 1,
#   ('School Reputation', 'School Culture', 'School Curriculum'): 1,
#   ('Distance from Home', 'Subjects Offered', 'School Curriculum'): 2,
#   ('School Reputation', 'School Curriculum', 'School opportunities'): 1},
#  42: {('Extremely Necessary',
#    'To improve diversity and prevent homogeneity or ethnic bubbles forming.',
#    " Even if it doesn't help with improving interaction, I think living together in the same spaces is still better than complete segregation by natural or artificial forces"): 1,
#   ('Somewhat Necessary',
#    'More contact w ethnicities very important',
#    'NIL'): 1,
#   ('Somewhat Necessary', 'Ensure interaction across races', 'NIL'): 1,
#   ('Somewhat Necessary',
#    'necessaey to prevent clustering of similar ethnicities together',
#    'NIL'): 1,
#   ('Somewhat Necessary',
#    'Allow for different races to acknowledge one anothers existence so there will not be a "out of sight, out of mind" situation',
#    'NIL'): 1,
#   ('Somewhat Necessary',
#    'Ensures multiracial interaction and limits creation of ethnic enclaves',
#    'NIL'): 1,
#   ('Somewhat Necessary',
#    'Prevents the formation of obvious racial enclaves',
#    'NIL'): 1,
#   ('Somewhat Necessary',
#    'help balance races',
#    'hard for minorities to resell hdb apparently'): 1,
#   ('Neutral',
#    'there are pros and cons; seems to benefit/affect minorities more',
#    'NIL'): 1,
#   ('Somewhat Necessary',
#    'It is important that there is physical integration of the different races in Singapore to promote and faciliate interaction',
#    'It is not applicable especially since the EIP does not apply towards rental housing, in estates such as Simei, there has been an alarming increase (based on observation) in the number of expats from India given how there is Changi Business Park nearby, rental housing opposes EIP'): 1,
#   ('Somewhat Necessary',
#    'To ensure that there are interactions between different racial groups to understand each other more. ',
#    'Should enforce quotas for schools as well. Some schools, especially the SAP schools have majority Chinese students.'): 1,
#   ('Extremely Necessary',
#    'Ensures that there is some kind of diversity in the building, and people of minority races have a better chance at securing a house',
#    'Beyond policy, there could be more chances of everyday interaction among races'): 1,
#   ('Somewhat NOT Necessary', 'NIL', 'NIL'): 7,
#   ('Somewhat Necessary',
#    'To prevent people from the same race congregating, to promote interaction with other ethnicities.',
#    'NIL'): 1,
#   ('Extremely Necessary',
#    'Prevents ghettoisation of the poorest of neighbourhoods. With the EIP, disasters like racial conflicts and riots are averted.',
#    "Keep it. If possible, apply it to private housing, but otherwise don't mess with it. It is so easy to question the policy when the younger generations have forgotten how Singapore was without it. One only needs to look at the racial politics and conflicts in other countries around the world and understand how much of our current peace and stability is owed to the EIP."): 1,
#   ('Somewhat Necessary', 'NIL', 'NIL'): 3,
#   ('Neutral',
#    "People of the same race may naturally tend to congregate together. Hard to say whether it's a good thing or a bad thing, and if it should be regulated or not.",
#    'NIL'): 1,
#   ('Somewhat Necessary',
#    'EIP is beneficial as it prevents the creation of racial enclaves. (We already see this in some Condos in the East, for instance). Though, perhaps this forced mixing was more essential in the past. ',
#    'Makes selling and purchasing of houses a challenge for minorities!'): 1,
#   ('Extremely Necessary',
#    'minority groups will be unintentionally be left out (numbers game/historic socioeconomic disadvantage). good to enforce a bare minimum of diversity',
#    'we might not personally have felt it being relevant improved the status quo but i think our society would be worse without it?'): 1,
#   ('Somewhat Necessary', 'Prevent enclaves', 'NIL'): 1,
#   ('Neutral', 'NIL', 'NIL'): 9,
#   ('Neutral',
#    'Encourages interaction with people of different ethnicities',
#    'NIL'): 1,
#   ('Somewhat NOT Necessary',
#    'Dont think it’s needed to help different ethnicities interact with each other',
#    'NIL'): 1,
#   ('Somewhat Necessary',
#    'Engineers a mix in ethnicities, prevents ethnic enclaves, theoretically improves chances of interaction across different ethnicities.',
#    'NIL'): 1,
#   ('Somewhat Necessary',
#    'Improves diversity within public housing and prevents the formation of ethnic enclaves',
#    'NIL'): 1,
#   ('Somewhat Necessary',
#    "As a nation that used to struggle with racial tensions, there certainly were some benefits to EIP in a time of less certainty. I think it's become a little less relevant now and possibly a counterproductive measure towards racial harmony. Nonetheless, I cannot imagine the geographical congregation of races as doing any favours towards striving for a more equitable society.",
#    "Maybe reconsideration towards the ratios and how they're decided."): 1,
#   ('Somewhat Necessary',
#    'While ethnic integration should not have to be mandated in policy, legislating it might be a good first step to normalise presence of different ethnicities in shared spaces  ',
#    'NIL'): 1,
#   ('Somewhat Necessary',
#    'Maintain mix of ethnic groups in all public housing districts. Otherwise over time neighbourhoods may be race dominant and deter integration.',
#    'NIL'): 1,
#   ('Somewhat Necessary',
#    "I think it's somewhat not necessary since it has a lot of adverse implications. While well intentioned perhaps, it can inadvertently disadvantage, discriminate and penalise minority ethnicities, who may struggle to buy/sell flats as a result of the ethnic quota. Still, I acknowledge it's meant to foster greater multiethnic interaction and harmony, and prevent a certain block/neighbourhood/town from being dominated by a certain group and Singaporeans splitting into ethnic enclaves, so I'm also not 100% sure what the alternative would be. ",
#    'Even though I understand the positive intentions behind EIP, it also seems like a somewhat artificial, contributed and forced form of "diversity" that is imposed on us. Perhaps the true harmony and diversity can only be achieved if we allow it to form naturally and organically, rather than by using a mandatory law or regulatory policy. Sure, it will be hard, but that\'s the ideal.'): 1,
#   ('Neutral',
#    'I guess it prevents segregation but frankly I would have more interactions outside my neighbourhood (e.g. work or school) than inside.',
#    'NIL'): 1,
#   ('Somewhat Necessary',
#    'prevents clusters of people from same race forming tgt',
#    'NIL'): 1,
#   ('Somewhat Necessary', 'Prevent racial enclaves from forming', 'NIL'): 1,
#   ('Somewhat NOT Necessary',
#    "Won't interact with neighbours much anyway",
#    'Scrape it, lower housing prices'): 1}}

# %%
for index, row in newDF.iterrows():
    for start, end in colsDict.items():
        choice, freq = random.choice(list(freqTable[start].items()))
        for i in range(start, end):
            newDF.at[index, "COL"+str(i)] = choice[i-start]
        if freq == 1:
            freqTable[start].pop(choice)
        else:
            freqTable[start][choice] -= 1

# %%
newDF
# Out:
#     COL1      COL2         COL3                         COL4  \
# 0     24   Chinese  Singaporean                    Pasir Ris
# 1     29    Indian  Singaporean                   Ang Mo Kio
# 2     25     Malay  Singaporean                      Punggol
# 3     19     Malay  Singaporean                  Jurong West
# 4     24    Indian       Indian                Choa Chu Kang
# 5     23    Indian       Indian                    Woodlands
# 6     30   Chinese  Singaporean                   Ang Mo Kio
# 7     30    Indian  Singaporean  I do not live in a HDB Town
# 8     21   Chinese  Singaporean                      Hougang
# 9     22  Eurasian  Singaporean  I do not live in a HDB Town
# 10    39   Chinese  Singaporean                       Bishan
# 11    22    Indian  Singaporean                    Woodlands
# 12    20   Chinese  Singaporean                  Jurong East
# 13    22    Indian  Singaporean                       Bishan
# 14    21   Chinese  Singaporean                    Woodlands
# 15    23    Indian  Singaporean  I do not live in a HDB Town
# 16    21   Chinese  Singaporean  I do not live in a HDB Town
# 17    27   Chinese  Singaporean                  Bukit Batok
# 18    21   Chinese  Singaporean                      Hougang
# 19    18   Chinese  Singaporean                Choa Chu Kang
# 20    22   Chinese  Singaporean                     Tampines
# 21    21   Chinese  Singaporean                        Bedok
# 22    21   Chinese  Singaporean                   Queenstown
# 23    23   Chinese  Singaporean                    Woodlands
# 24    25   Chinese  Singaporean                        Bedok
# 25    24   Chinese  Singaporean                   Ang Mo Kio
# 26    21   Chinese  Singaporean                       Bishan
# 27    25   Chinese  Singaporean                       Bishan
# 28    21   Chinese  Singaporean                   Queenstown
# 29    24   Chinese  Singaporean                  Bukit Timah
# 30    23   Chinese  Singaporean                      Punggol
# 31    23   Chinese  Singaporean                Choa Chu Kang
# 32    24   Chinese  Singaporean                     Tampines
# 33    22   Chinese  Singaporean                    Serangoon
# 34    22   Chinese  Singaporean                     Clementi
# 35    25   Chinese  Singaporean                     Clementi
# 36    22   Chinese  Singaporean                     Clementi
# 37    22   Chinese  Singaporean                Bukit Panjang
# 38    24   Chinese  Singaporean  I do not live in a HDB Town
# 39    23   Chinese  Singaporean                       Bishan
# 40    22   Chinese  Singaporean                       Bishan
# 41    22   Chinese  Singaporean                       Bishan
# 42    23   Chinese  Singaporean                    Pasir Ris
# 43    24   Chinese  Singaporean                    Pasir Ris
# 44    24   Chinese  Singaporean                      Hougang
# 45    23   Chinese  Singaporean  I do not live in a HDB Town
# 46    22   Chinese  Singaporean                     Sengkang
# 47    24   Chinese  Singaporean                     Tampines
# 48    23   Chinese  Singaporean                       Yishun
#
#                     COL5            COL6      COL7     COL8  COL9  COL10  ...  \
# 0   Public Housing (HDB)  Executive Flat   1 to 10        0   5.5    0.0  ...
# 1   Public Housing (HDB)          4-Room   1 to 10        0   5.5    0.0  ...
# 2   Public Housing (HDB)          4-Room         0        0   0.0    0.0  ...
# 3   Public Housing (HDB)          4-Room   1 to 10        0   5.5    0.0  ...
# 4   Public Housing (HDB)          5-Room  11 to 20  1 to 10  15.5    5.5  ...
# 5   Public Housing (HDB)          4-Room   1 to 10        0   5.5    0.0  ...
# 6   Public Housing (HDB)          5-Room   1 to 10        0   5.5    0.0  ...
# 7                Private        Bungalow   1 to 10        0   5.5    0.0  ...
# 8                Private   Semi-detached   1 to 10        0   5.5    0.0  ...
# 9                Private     Condominium         0        0   0.0    0.0  ...
# 10               Private   Semi-detached   1 to 10  1 to 10   5.5    5.5  ...
# 11               Private        Bungalow  11 to 20  1 to 10  15.5    5.5  ...
# 12  Public Housing (HDB)  Executive Flat   1 to 10  1 to 10   5.5    5.5  ...
# 13               Private     Condominium   1 to 10  1 to 10   5.5    5.5  ...
# 14  Public Housing (HDB)  Executive Flat  11 to 20  1 to 10  15.5    5.5  ...
# 15               Private        Detached   1 to 10  1 to 10   5.5    5.5  ...
# 16               Private         Terrace   1 to 10        0   5.5    0.0  ...
# 17  Public Housing (HDB)          4-Room         0        0   0.0    0.0  ...
# 18  Public Housing (HDB)          4-Room   1 to 10  1 to 10   5.5    5.5  ...
# 19  Public Housing (HDB)          4-Room         0        0   0.0    0.0  ...
# 20  Public Housing (HDB)          5-Room   1 to 10  1 to 10   5.5    5.5  ...
# 21  Public Housing (HDB)          5-Room         0        0   0.0    0.0  ...
# 22               Private     Condominium         0        0   0.0    0.0  ...
# 23  Public Housing (HDB)          3-Room   1 to 10        0   5.5    0.0  ...
# 24  Public Housing (HDB)          5-Room   1 to 10  1 to 10   5.5    5.5  ...
# 25  Public Housing (HDB)          4-Room   1 to 10        0   5.5    0.0  ...
# 26  Public Housing (HDB)          4-Room   1 to 10  1 to 10   5.5    5.5  ...
# 27  Public Housing (HDB)  Executive Flat         0        0   0.0    0.0  ...
# 28               Private     Condominium   1 to 10        0   5.5    0.0  ...
# 29               Private     Condominium   1 to 10  1 to 10   5.5    5.5  ...
# 30  Public Housing (HDB)          4-Room   1 to 10        0   5.5    0.0  ...
# 31  Public Housing (HDB)          5-Room   1 to 10  1 to 10   5.5    5.5  ...
# 32               Private     Condominium   1 to 10        0   5.5    0.0  ...
# 33               Private     Condominium   1 to 10  1 to 10   5.5    5.5  ...
# 34               Private     Condominium   1 to 10        0   5.5    0.0  ...
# 35               Private     Condominium   1 to 10        0   5.5    0.0  ...
# 36  Public Housing (HDB)          4-Room         0        0   0.0    0.0  ...
# 37               Private     Condominium   1 to 10        0   5.5    0.0  ...
# 38               Private         Terrace         0        0   0.0    0.0  ...
# 39  Public Housing (HDB)  Executive Flat         0        0   0.0    0.0  ...
# 40  Public Housing (HDB)          5-Room         0        0   0.0    0.0  ...
# 41  Public Housing (HDB)          5-Room         0        0   0.0    0.0  ...
# 42  Public Housing (HDB)          5-Room         0        0   0.0    0.0  ...
# 43  Public Housing (HDB)          5-Room         0        0   0.0    0.0  ...
# 44               Private     Condominium         0        0   0.0    0.0  ...
# 45               Private         Terrace         0        0   0.0    0.0  ...
# 46  Public Housing (HDB)          4-Room         0        0   0.0    0.0  ...
# 47  Public Housing (HDB)          4-Room         0        0   0.0    0.0  ...
# 48  Public Housing (HDB)     Mansionette         0        0   0.0    0.0  ...
#
#                          COL35  \
# 0   Neither agree nor disagree
# 1               Somewhat agree
# 2               Somewhat agree
# 3               Somewhat agree
# 4               Strongly agree
# 5               Somewhat agree
# 6               Strongly agree
# 7               Strongly agree
# 8               Strongly agree
# 9               Strongly agree
# 10  Neither agree nor disagree
# 11              Strongly agree
# 12              Somewhat agree
# 13              Somewhat agree
# 14              Somewhat agree
# 15              Strongly agree
# 16              Somewhat agree
# 17              Strongly agree
# 18  Neither agree nor disagree
# 19              Strongly agree
# 20              Strongly agree
# 21              Strongly agree
# 22              Somewhat agree
# 23              Somewhat agree
# 24              Strongly agree
# 25              Strongly agree
# 26              Somewhat agree
# 27              Strongly agree
# 28              Strongly agree
# 29              Somewhat agree
# 30              Strongly agree
# 31              Strongly agree
# 32              Strongly agree
# 33              Strongly agree
# 34              Strongly agree
# 35              Strongly agree
# 36              Somewhat agree
# 37              Strongly agree
# 38              Strongly agree
# 39              Somewhat agree
# 40              Somewhat agree
# 41              Somewhat agree
# 42              Somewhat agree
# 43              Somewhat agree
# 44              Somewhat agree
# 45              Somewhat agree
# 46              Somewhat agree
# 47              Somewhat agree
# 48              Somewhat agree
#
#                                                 COL36                 COL37  \
# 0                                       Hawker Centre             Bus Stops
# 1                                        MRT Stations         Shopping Mall
# 2                                        MRT Stations         Shopping Mall
# 3                                        MRT Stations             Bus Stops
# 4                                        MRT Stations         Shopping Mall
# 5                                        MRT stations             Bus Stops
# 6                                       Shopping Mall          MRT Stations
# 7   Places where food can be purchased (eg market,...          MRT stations
# 8                                    Place of Worship          MRT Stations
# 9                                        MRT Stations  Tertiary Institution
# 10                                          Bus Stops          MRT Stations
# 11                                       MRT Stations         Shopping Mall
# 12                                       MRT stations             Bus Stops
# 13                                       MRT stations         Shopping Mall
# 14                                       MRT Stations             Bus Stops
# 15                                          Bus Stops         Shopping Mall
# 16                                      Shopping Mall          MRT stations
# 17                                       MRT stations         Shopping Mall
# 18                                      Shopping Mall          MRT stations
# 19                                          Bus Stops             Childcare
# 20                                       MRT Stations         Shopping Mall
# 21                                      Shopping Mall          MRT stations
# 22                                       MRT Stations         Shopping Mall
# 23                                       MRT stations         Shopping Mall
# 24                                       MRT stations             Bus Stops
# 25                                       MRT stations             Bus Stops
# 26                                      Shopping Mall          MRT Stations
# 27                                          Bus Stops          MRT stations
# 28                                       MRT Stations         Shopping Mall
# 29                                       MRT stations             Bus Stops
# 30                                       MRT Stations             Bus Stops
# 31                                       MRT stations             Bus Stops
# 32                                          Bus Stops          MRT Stations
# 33                                       MRT Stations             Bus Stops
# 34                                          Bus Stops          MRT Stations
# 35                                       MRT Stations         Shopping Mall
# 36                                       MRT Stations             Bus Stops
# 37                                       MRT Stations             Bus Stops
# 38                                       MRT Stations             Bus Stops
# 39                                          Bus Stops          MRT Stations
# 40                                       MRT Stations             Bus Stops
# 41                                       MRT Stations             Bus Stops
# 42                                       MRT Stations             Bus Stops
# 43                                          Bus Stops          MRT Stations
# 44                                       MRT Stations             Bus Stops
# 45                                       MRT Stations             Bus Stops
# 46                                       MRT Stations             Bus Stops
# 47                                       MRT Stations             Bus Stops
# 48                                       MRT Stations             Bus Stops
#
#                  COL38               COL39  \
# 0         MRT stations   School Curriculum
# 1             Eateries   School Reputation
# 2            Bus Stops   School Curriculum
# 3        Shopping Mall   School Curriculum
# 4            Bus Stops   School Curriculum
# 5        Shopping Mall   School Reputation
# 6                Parks   School Curriculum
# 7       Primary School  Distance from Home
# 8        Shopping Mall   School Reputation
# 9        Shopping Mall    Subjects Offered
# 10       Shopping Mall   School Reputation
# 11    Secondary School  Distance from Home
# 12       Shopping Mall   School Reputation
# 13           Bus Stops   School Curriculum
# 14         Coffee shop   School Curriculum
# 15        MRT Stations  Distance from Home
# 16           Bus Stops   School Curriculum
# 17           Bus Stops   School Reputation
# 18           Bus Stops   School Reputation
# 19       Shopping Mall   School Curriculum
# 20    Sport facilities   School Curriculum
# 21           Bus Stops   School Reputation
# 22           Bus Stops   School Curriculum
# 23  Cheap food options   School Curriculum
# 24      Primary School    Subjects Offered
# 25       Hawker Centre   School Reputation
# 26           Bus Stops   School Reputation
# 27      Primary School   School Curriculum
# 28           Bus Stops   School Curriculum
# 29       Hawker Centre   School Curriculum
# 30       Shopping Mall   School Curriculum
# 31       Shopping Mall   School Reputation
# 32       Shopping Mall  Distance from Home
# 33       Shopping Mall   School Curriculum
# 34       Shopping Mall  Distance from Home
# 35           Bus Stops   School Reputation
# 36       Shopping Mall  Distance from Home
# 37       Shopping Mall   School Curriculum
# 38       Shopping Mall   School Reputation
# 39       Shopping Mall   School Reputation
# 40       Shopping Mall   School Curriculum
# 41       Shopping Mall   School Reputation
# 42       Shopping Mall   School Curriculum
# 43       Shopping Mall   School Reputation
# 44       Shopping Mall   School Reputation
# 45       Shopping Mall   School Reputation
# 46       Shopping Mall   School Reputation
# 47       Shopping Mall   School Reputation
# 48       Shopping Mall   School Reputation
#
#                                                 COL40  \
# 0                          Extracurricular Programmes
# 1                                      School Culture
# 2                                  Distance from Home
# 3                                  Distance from Home
# 4                                   School Reputation
# 5                                    Subjects Offered
# 6                                  Distance from Home
# 7                                   School Reputation
# 8                                   School Curriculum
# 9                                  Distance from Home
# 10                                  School Curriculum
# 11                                   Subjects Offered
# 12                                 Distance from Home
# 13                                  School Reputation
# 14                                   Subjects Offered
# 15                                  School Reputation
# 16                                   Subjects Offered
# 17                                  School Curriculum
# 18                                  School Curriculum
# 19                                  School Reputation
# 20                                  School Reputation
# 21                                 Distance from Home
# 22                                  School Reputation
# 23                                  School Reputation
# 24                                  School Reputation
# 25                                  School Curriculum
# 26  People and culture (eg classmates, students, t...
# 27                                  School Reputation
# 28                                  School Reputation
# 29                                  School Reputation
# 30                                  School Reputation
# 31                                  School Curriculum
# 32                                   Subjects Offered
# 33                                  School Reputation
# 34                                   Subjects Offered
# 35                                  School Curriculum
# 36                                   Subjects Offered
# 37                                  School Reputation
# 38                                  School Curriculum
# 39                                 Distance from Home
# 40                                  School Reputation
# 41                                 Distance from Home
# 42                                  School Reputation
# 43                                  School Curriculum
# 44                                 Distance from Home
# 45                                 Distance from Home
# 46                                 Distance from Home
# 47                                  School Curriculum
# 48                                  School Curriculum
#
#                          COL41                   COL42  \
# 0           Distance from Home     Extremely Necessary
# 1            School Curriculum      Somewhat Necessary
# 2             Subjects Offered      Somewhat Necessary
# 3            School Reputation      Somewhat Necessary
# 4           Distance from Home     Extremely Necessary
# 5            School Curriculum      Somewhat Necessary
# 6             Subjects Offered  Somewhat NOT Necessary
# 7            School Curriculum      Somewhat Necessary
# 8           Distance from Home                 Neutral
# 9            School Reputation                 Neutral
# 10          Distance from Home      Somewhat Necessary
# 11           School Reputation      Somewhat Necessary
# 12           School Curriculum                 Neutral
# 13          Distance from Home     Extremely Necessary
# 14           School Reputation      Somewhat Necessary
# 15           School Curriculum      Somewhat Necessary
# 16  Extracurricular Programmes      Somewhat Necessary
# 17            Subjects Offered      Somewhat Necessary
# 18            Subjects Offered      Somewhat Necessary
# 19            Subjects Offered     Extremely Necessary
# 20          Distance from Home      Somewhat Necessary
# 21           School Curriculum  Somewhat NOT Necessary
# 22  Extracurricular Programmes      Somewhat Necessary
# 23            Subjects Offered      Somewhat Necessary
# 24          Distance from Home      Somewhat Necessary
# 25        School opportunities      Somewhat Necessary
# 26           School Curriculum      Somewhat Necessary
# 27          Distance from Home      Somewhat Necessary
# 28            Subjects Offered  Somewhat NOT Necessary
# 29          Distance from Home      Somewhat Necessary
# 30            Subjects Offered                 Neutral
# 31            Subjects Offered                 Neutral
# 32           School Reputation      Somewhat Necessary
# 33            Subjects Offered  Somewhat NOT Necessary
# 34           School Curriculum      Somewhat Necessary
# 35          Distance from Home                 Neutral
# 36           School Curriculum      Somewhat Necessary
# 37            Subjects Offered  Somewhat NOT Necessary
# 38          Distance from Home  Somewhat NOT Necessary
# 39           School Curriculum                 Neutral
# 40            Subjects Offered                 Neutral
# 41           School Curriculum                 Neutral
# 42            Subjects Offered                 Neutral
# 43  Extracurricular Programmes  Somewhat NOT Necessary
# 44           School Curriculum                 Neutral
# 45           School Curriculum                 Neutral
# 46           School Curriculum  Somewhat NOT Necessary
# 47  Extracurricular Programmes  Somewhat NOT Necessary
# 48  Extracurricular Programmes                 Neutral
#
#                                                 COL43  \
# 0   minority groups will be unintentionally be lef...
# 1                                    Prevent enclaves
# 2   Allow for different races to acknowledge one a...
# 3   While ethnic integration should not have to be...
# 4   Prevents ghettoisation of the poorest of neigh...
# 5   EIP is beneficial as it prevents the creation ...
# 6   Dont think it’s needed to help different ethni...
# 7                                  help balance races
# 8   People of the same race may naturally tend to ...
# 9   there are pros and cons; seems to benefit/affe...
# 10               Prevent racial enclaves from forming
# 11  As a nation that used to struggle with racial ...
# 12  Encourages interaction with people of differen...
# 13  To improve diversity and prevent homogeneity o...
# 14  To prevent people from the same race congregat...
# 15  I think it's somewhat not necessary since it h...
# 16                    Ensure interaction across races
# 17  Engineers a mix in ethnicities, prevents ethni...
# 18  Ensures multiracial interaction and limits cre...
# 19  Ensures that there is some kind of diversity i...
# 20  Maintain mix of ethnic groups in all public ho...
# 21                                                NIL
# 22                                                NIL
# 23  It is important that there is physical integra...
# 24                                                NIL
# 25                                                NIL
# 26  prevents clusters of people from same race for...
# 27  To ensure that there are interactions between ...
# 28         Won't interact with neighbours much anyway
# 29          More contact w ethnicities very important
# 30  I guess it prevents segregation but frankly I ...
# 31                                                NIL
# 32  Improves diversity within public housing and p...
# 33                                                NIL
# 34  Prevents the formation of obvious racial enclaves
# 35                                                NIL
# 36  necessaey to prevent clustering of similar eth...
# 37                                                NIL
# 38                                                NIL
# 39                                                NIL
# 40                                                NIL
# 41                                                NIL
# 42                                                NIL
# 43                                                NIL
# 44                                                NIL
# 45                                                NIL
# 46                                                NIL
# 47                                                NIL
# 48                                                NIL
#
#                                                 COL44
# 0   we might not personally have felt it being rel...
# 1                                                 NIL
# 2                                                 NIL
# 3                                                 NIL
# 4   Keep it. If possible, apply it to private hous...
# 5   Makes selling and purchasing of houses a chall...
# 6                                                 NIL
# 7        hard for minorities to resell hdb apparently
# 8                                                 NIL
# 9                                                 NIL
# 10                                                NIL
# 11  Maybe reconsideration towards the ratios and h...
# 12                                                NIL
# 13   Even if it doesn't help with improving intera...
# 14                                                NIL
# 15  Even though I understand the positive intentio...
# 16                                                NIL
# 17                                                NIL
# 18                                                NIL
# 19  Beyond policy, there could be more chances of ...
# 20                                                NIL
# 21                                                NIL
# 22                                                NIL
# 23  It is not applicable especially since the EIP ...
# 24                                                NIL
# 25                                                NIL
# 26                                                NIL
# 27  Should enforce quotas for schools as well. Som...
# 28                    Scrape it, lower housing prices
# 29                                                NIL
# 30                                                NIL
# 31                                                NIL
# 32                                                NIL
# 33                                                NIL
# 34                                                NIL
# 35                                                NIL
# 36                                                NIL
# 37                                                NIL
# 38                                                NIL
# 39                                                NIL
# 40                                                NIL
# 41                                                NIL
# 42                                                NIL
# 43                                                NIL
# 44                                                NIL
# 45                                                NIL
# 46                                                NIL
# 47                                                NIL
# 48                                                NIL
#
# [49 rows x 44 columns]
